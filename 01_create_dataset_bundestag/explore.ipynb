# %%
import pandas as pd
from datetime import datetime
from datetime import UTC

# %%
df = pd.read_json("Bundestagsreden_senti_pos_neg_summarized.json")

# %%
begin = min(list(df['Datum']))
end = max(list(df['Datum']))

# %%
print(datetime.fromtimestamp(int(begin/1000), UTC).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2017-10-24 00:00:00

# %%
print(datetime.fromtimestamp(int(end/1000), UTC).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2024-09-27 00:00:00

# %%
df
# Out:
#        Wahlperiode  Sitzungsnummer       Rede_ID          Datum Beginn  \
# 0               20              89   ID208902000  1677801600000   9:00
# 1               20              11   ID201106400  1642032000000   9:00
# 2               19             139  ID1913910300  1579046400000  13:00
# 3               19              43   ID194303100  1530230400000  09:00
# 4               19             187  ID1918701000  1604016000000   9:00
# ...            ...             ...           ...            ...    ...
# 34169           19             148  ID1914810500  1583280000000  13:00
# 34170           20               2    ID20202000  1636588800000   9:00
# 34171           20              18   ID201808500  1645142400000   9:00
# 34172           19             147  ID1914705100  1581638400000   9:00
# 34173           19              86   ID198605400  1552521600000  09:00
#
#       Schluss  Redner_ID Redner_Titel                      Redner_Name  \
# ...
